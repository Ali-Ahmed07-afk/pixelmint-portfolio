# %%
print("I am Ali Ahmed")
# Out:
# I am Ali Ahmed

# %%
name = "Ali"
age = 18
is_student = True
print(f"My name is {name} and I am {age} is years old")
# Out:
# My name is Ali and I am 18 is years old
